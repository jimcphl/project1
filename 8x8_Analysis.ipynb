# %% [markdown]
# # 8x8
#
# - https://jiunyiyang.me/2020/09/05/google-tag-manager-tutorial-youtube-video-tracking/
#
# #### learning
# - Google Analytics SEO tools Basecamp Facebook Advertising Proofreading Google Search Console
# - https://github.com/trevorfox/digital-marketing-technical-fundamentals
# - https://skillshop.exceedlms.com/student/catalog/list?category_ids=53-google-ads?use_local=true
#
# #### salesforces
# - tflung@centersplan.com
#
#
# #### Computer
# - bF5xxxxx98
#
# #### Daysforce
# - bF5xxxxx98
# - mycenters
# - TZE FUNG.LUNG
#
# ##### 8x8
# - https://sso.8x8.com/sso/login
# - Pass4new$
#
#
# - https://centersplan.2leap.com/
# - 881lfnrd
#
# - https://sso.8x8.com/v2/login
# - Pass4new$
#
# #### github
# - jimcphl
# - 899xxxx05a
#
# #### google
# - jimcphl@gmail.com
# - 899xxxx5
#
# #### cloud.ibm.com
# - jimcphl@gmail.com
# - 505xxx98aH
#
# #### login.live.com / onedrive.live.com
# - jimcphl@gmail.com
# - 89xxxx05a
#
# #### https://centersplanforhealthyliving.my.salesforce.com/
# - TFLung@centersplan.com
# - 89xxxx05a
#
# #### app.smartsheet.com
# - TFLung@centersplan.com
# - Pass4new$Pass
#
# #### CaseTracker
# - tflung
# - aH89xxxxxx5
#
# #### cheat sheet
# - https://cheatography.com/tag/google-analytics/
#
# #### google analystic test
# - jimcphl@gmail.com
# - pw: 50xxxxx8
#
# #### AWS
# - jimcphl@gmail.com
# - Hxxd1xx4@
#
# #### CDL a practical test
# - https://uniontestprep.com/cdl/study-guide/air-brakes-test/pages/1
# - https://www.thetruckersreport.com/cdl-practice-tests/air-brakes/
# - https://www.epermittest.com/new-york/ny-cdl-practice-dmv-cheat-sheet
# - https://www.cristcdl.com/new-york/ny-cdl-practice-tests/
# - https://www.test-guide.com/free-cdl-practice-tests.html
# - https://www.dmv-written-test.com/
#
#
# #### book
# - https://datacadamia.com/
# - https://kandi.openweaver.com/home
#
# #### Leetcode
# - https://leetcode.com/explore/
# - https://www.hackerrank.com/
#
# #### SQL
# - https://github.com/Thomas-George-T/HackerRank-SQL-Challenges-Solutions
# - https://github.com/KimTisott/HackerRank-Solutions/tree/main/SQL
# - https://www.w3schools.com/sql/
# - https://www.w3schools.com/sql/sql_distinct.asp
# - https://www.sqlservertutorial.net/install-sql-server/
# - https://sqlzoo.net/wiki/SELECT_basics
# - https://tests4geeks.com/sql-online-test
# - https://pgexercises.com/questions/basic/where2.html
# - https://www.geeksforgeeks.org/sql-ddl-dql-dml-dcl-tcl-commands/
# - https://sqlzoo.net/wiki/The_JOIN_operation
# - https://github.com/edsfocci/SQL-SQL_Zoo/blob/master/06_the_join_operation.sql
# - https://www.sqlcourse2.com/intro2.html
#
#
# #### mode
# - jimcphl
# - Hxxd1xx4
#
# #### Power Automate
# https://us.flow.microsoft.com/en-us/connectors/shared_sharepointonline/sharepoint/
#
# #### node.js
# - https://www.w3schools.com/nodejs/nodejs_npm.asp
#
# #### auto update data
# - https://www.freecodecamp.org/news/how-to-create-auto-updating-data-visualizations-in-python-with-matplotlib-and-aws/
#
# #### django
# - https://docs.djangoproject.com/en/3.2/intro/tutorial01/
#
# #### Google Tag Manager
# - https://blog.hootsuite.com/how-to-set-up-google-analytics/
# - https://mashmetrics.com/sample-google-tag-manager-container/
# - https://datasupplied.com/google-tag-manager/gtm-implementation/
# - https://awoo.ai/zh-hant/blog/gtm-ga-implement/
# - https://inboundmarketing.com.tw/websites-optimization/gtm%E6%95%99%E5%AD%B8-%E6%96%B0%E6%89%8B%E8%A7%80%E5%BF%B5%E7%AF%87.html
# - https://mixedanalytics.com/blog/google-%E4%BB%A3%E7%A2%BC%E7%AE%A1%E7%90%86%E5%B7%A5%E5%85%B7-youtube-%E5%BD%B1%E7%89%87%E8%BF%BD%E8%B9%A4/
# - https://jiunyiyang.me/2020/09/05/google-tag-manager-tutorial-youtube-video-tracking/
#
# #### Google ads certicate
# - https://skillshop.exceedlms.com/student/catalog/list?category_ids=53-google-ads?use_local=true
# - https://support.google.com/analytics/answer/1033961?hl=en&%3Bvid=1-635760473728266369-729394007#zippy=%2Cin-this-article
# - https://ads.google.com/home/how-it-works/
#
# #### AB test
# - https://www.upbuild.io/blog/google-optimize-data-studio/
# - https://www.optimizely.com/optimization-glossary/ab-testing/
# - https://blog.hubspot.com/marketing/a-b-testing-tools
# - https://towardsdatascience.com/ab-testing-with-python-e5964dd66143
#
# #### google analystics
#
# - https://www.certificationanswers.com/en/category/google-analytics-certification/
# - https://www.timessquareadcoalition.org/google-analytics-individual-qualification-exam-answers/
# - https://coodie.com/analytics-certification-exam-answers.php
# - https://quizlet.com/324384842/google-analytics-assessment-three-flash-cards/
# - https://analytics.google.com/analytics/academy/course/6/unit/1/lesson/3
# - https://skillshop.exceedlms.com/student/path/2938-google-analytics-individual-qualification
# - https://www.websiteplanet.com/blog/ultimate-beginners-guide-google-analytics/
# - https://www.mainstreetroi.com/how-to-use-google-analytics-to-track-all-of-your-marketing/
# - https://marketingplatform.google.com/about/analytics/#?modal_active=none
# - https://firstsiteguide.com/google-analytics-for-wordpress/
# - https://analytics.google.com/analytics/web/?authuser=0#/p262985576/reports/reportinghub
# - https://www.mainstreetroi.com/how-to-use-google-analytics-to-track-all-of-your-marketing/
# - https://www.answerout.com/google-analytics-for-beginners-answers-assessment-2
# - https://www.tutorialkart.com/salesforce-tutorial/salesforce-administrator/
# - https://www.salesforcetutorial.com/
# - https://blog.hubspot.com/marketing/google-analytics
# - https://support.google.com/analytics/?hl=en#topic=10737980
# #### Email tracking
# - https://sendpulse.com/blog/google-analytics-email-tracking
# #### UTM tracking
# - https://docs.google.com/spreadsheets/d/1tf3_SczMMTTf-ZJ9Bkb70xps_DPGLBTd4wkHPyadKSA/edit?hl=en_US&;usp=sharing&hl=en_US#gid=1
# #### URL builder
# - https://ga-dev-tools.web.app/campaign-url-builder/
#
#
#
# #### google bigquery
# - https://cloud.google.com/certification?authuser=1
#
# #### salesforce
# - https://trailhead.salesforce.com/credentials/administrator
# - jimcphl@gmail.com
#
# #### kafka
# - https://towardsdatascience.com/kafka-python-explained-in-10-lines-of-code-800e3e07dad1
#
# #### pyspark
# - https://www.exxactcorp.com/blog/Deep-Learning/the-benefits-examples-of-using-apache-spark-with-pyspark
# - https://www.guru99.com/pyspark-tutorial.html
#
# #### azure
# - https://docs.microsoft.com/en-us/learn/azure/
#
# - Jim Lung - Profile | Tableau Public
# jimcphl@gmail.com
# 5051xxx8aH@
#
# #### tableau
# - https://medium.com/@daan.tor/use-python-to-create-network-graphs-in-tableau-2e03950e7cd4
# - https://www.clearlyandsimply.com/clearly_and_simply/2012/12/build-network-graphs-in-tableau.html
# - https://www.doingdata.org/blog/how-to-create-a-kpi-scorecard-in-tableau
# - https://public.tableau.com/views/scorecard_cleaned/Scorecard?:embed=y&:showVizHome=no&:display_count=y&:display_static_image=y&:bootstrapWhenNotified=true
# - https://public.tableau.com/en-us/search/all/%23scorecards
# - https://senturus.com/blog/creating-a-big-numbers-kpi-dashboard-in-tableau/
# - https://medium.com/@daan.tor/use-python-to-create-network-graphs-in-tableau-2e03950e7cd4
# - https://www.hashtagtechgeek.com/2019/10/download-40-interactive-tableau-resume.html
# - https://data-flair.training/blogs/tableau-reference-band/
#
# #### airflow
# - https://github.com/hgrif/airflow-tutorial
# - https://towardsdatascience.com/a-complete-introduction-to-apache-airflow-b7e238a33df
# - http://airflow.apache.org/docs/apache-airflow/stable/installation/installing-from-pypi.html
# - https://towardsdatascience.com/a-complete-introduction-to-apache-airflow-b7e238a33df
# - https://medium.com/abn-amro-developer/data-pipeline-orchestration-on-steroids-apache-airflow-tutorial-part-1-87361905db6d
# - https://stackoverflow.com/questions/51977855/installing-apache-airflow-in-conda-environment
#
# #### snowflake
# - https://towardsdatascience.com/getting-started-with-snowflake-%EF%B8%8F-35d395103034
# - https://docs.snowflake.com/en/sql-reference/sql-ddl-summary.html
# - https://www.snowflake.com/snowflake-essentials-training/
#
# #### arcgis
# - https://www.arcgis.com/home/index.html
#
# #### Redshift
# - https://www.tutorialspoint.com/amazon_web_services/amazon_web_services_redshift.htm
#
# #### aws antenta
# - https://docs.aws.amazon.com/zh_tw/athena/latest/ug/getting-started.html
#
#
# #### ibm data cloud
# - https://dataplatform.cloud.ibm.com/docs/content/wsj/landings/wsl.html
# - https://www.ibm.com/cloud/object-storage/pricing
# - https://eu-gb.dataplatform.cloud.ibm.com/home2?context=cpdaas
#
# #### google cloud
# - https://cloud.google.com/docs
# - jimcphl@gmail.com
# - https://support.google.com/analytics/answer/4419694?hl=zh-Hant#zippy=%2C%E6%9C%AC%E6%96%87%E5%85%A7%E5%AE%B9
#
#
# #### cloud engineer
# - https://cloud.google.com/certification/cloud-engineer
# - https://hackr.io/blog/gcp-certifications
#
# #### Daily
# - daily progress report
# - SALES TEAM Weekly MAP STATUS
# - Application Received
#
# #### Mid
# - CMS
# - Disenrollment Analysis
# - Agent Dashboard for Sales Team
#
# #### Weekly
# - 8x8 (mon)
#
# #### End
# - Disenrollment data
# - Agent Compensation - payroll reconcilation
# - Financial Team
# - Change Daily progress report and percentage
# - Disenrollment Survey
# - EVENTS PROGRESS REPORT
# - DISENROLLMENT AND RAPID DISENROLLMENT ANALYSIS
#
#
# Schedule
# - exam citizen
# - exam insurance
#
# work
# - gcp
# - aws
# - azure
# - django
# - salesforce
# - tableau public

# %%
import pandas as pd
import os

# DualEligibleMembers.xlsx
#pd.read_excel('DualEligibleMembers.xlsx', index_col=0)

#url = "S:\ENROLLMENT\ENROLLMENT-PUBLIC\MEDICARE\MAPD\MAPD&SNP Roster_2021.xlsx"

#url = "C:\\Users\\tflung\\OneDrive\\Documents\\MAPD&SNP Roster_2021.xlsx"

import numpy as np
df = pd.read_excel('RecentCallsSummary.xlsx', skiprows = 5)

# Rename

df = df.rename(columns={'Abandon Time': 'AbandonTime'})
df = df.rename(columns={'Call Date': 'CallDate'})
df = df.rename(columns={'Call Direction': 'CallDirection'})
df = df.rename(columns={'Call Duration': 'CallDuration'})
df = df.rename(columns={'Abandon Time': 'AbandonTime'})
df = df.rename(columns={'Caller Name': 'CallerName'})

df = df.rename(columns={'Call Start Time': 'CallStartTime'})
df = df.rename(columns={'Call Type': 'CallType'})
df = df.rename(columns={'Caller Phone Number': 'CallerPhoneNumber'})
df = df.rename(columns={'Destination Number': 'DestinationNumber'})
df = df.rename(columns={'Hangup by': 'Hangupby'})

# change to seconds
#df['seconds'] = df['CallDuration'].dt.total_seconds().astype(int)
df['CallDuration'] = pd.to_datetime(df['CallDuration'], errors='coerce')
df['CallDurationseconds'] = df['CallDuration'].dt.second.round(0)

df['CallDuration'] = pd.to_datetime(df['CallDuration'], errors='coerce')
df['CallDurationseconds'] = df['CallDuration'].dt.second.round(0)

df = df[(df['CallDurationseconds'] >= 10)]

print (df)
# Out:
# C:\Users\tflung\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      AbandonTime             Agents    CallDate CallDirection  \
# 0     00:00:12.1                NaN  03/05/2022       Inbound
# 1     00:00:00.0  Katiria Fernandez  03/04/2022       Inbound
# 2     00:00:00.0  Katiria Fernandez  03/04/2022       Inbound
# 5     00:00:00.0  Katiria Fernandez  03/04/2022       Inbound
# 6     00:00:00.0                NaN  03/04/2022       Inbound
# ...          ...                ...         ...           ...
# 3355  00:00:00.0  Katiria Fernandez  03/08/2021       Inbound
# 3357  00:00:00.0                NaN  03/08/2021       Inbound
# 3358  00:03:23.5   Carolina Zuluaga  03/07/2021       Inbound
# 3359  00:00:00.0   Carolina Zuluaga  03/07/2021       Inbound
# 3360  00:00:00.0   Carolina Zuluaga  03/07/2021       Inbound
# ...

# %% [raw]
# # https://datatofish.com/export-dataframe-to-excel/
#
# #df7.to_excel(r'7.xlsx', index = False)
#
#
# with pd.ExcelWriter('8x8.xlsx',
#                   date_format='YYYY-MM-DD',
#                   datetime_format='YYYY-MM-DD') as writer:
#     df.to_excel(writer, index=False)

# %%
df.to_csv(r'8x8.csv', index = False)
