# %% [markdown]
# # Month Comparison

# %% [markdown]
# ### load data

# %%
import pandas as pd
import os

# DualEligibleMembers.xlsx
#pd.read_excel('DualEligibleMembers.xlsx', index_col=0)

url = "MAPD&SNP Roster_2021.xlsx"

df1=pd.read_excel(
     os.path.join(url),
     engine='openpyxl',
)
#df1

# Rename

df2 = df1.rename(columns={'Enrollment Date': 'EnrollDate'})
df2 = df2.rename(columns={'App Date': 'AppDate'})
df2 = df2.rename(columns={'Marketing Rep': 'Rep'})

# select columns

df3 = df2[['EnrollDate', 'LOB', 'Status', 'AppDate', 'Rep']]

# print this 2 days
#df3[(df3['AppDate'] >= '2021-01-19') & (df3['AppDate'] <= '2021-01-20')]
# Out:
# C:\Users\tflung\Downloads\WPy64-3870\python-3.8.7.amd64\lib\site-packages\openpyxl\worksheet\_reader.py:300: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# Total month comparison
df4 = df3[(df3['EnrollDate'] == '2021-01-01') | (df3['EnrollDate'] == '2021-02-01') | (df3['EnrollDate'] == '2021-03-01')]

#df4.head()

# Whole Team

df4 = df4[(df4['Rep'] == 'Yanery Fernandez') 
          | (df4['Rep'] == 'Ivonne Cedeno')
          | (df4['Rep'] == 'James (Shiou-Hao) Lu')
          | (df4['Rep'] == 'Monalisa Crossway')
          | (df4['Rep'] == 'Laura Lou Seefeldt')
          | (df4['Rep'] == 'Griselle Leonardo')
          | (df4['Rep'] == 'Shelly Bobb')
          | (df4['Rep'] == 'Zhen Zhu')
          | (df4['Rep'] == 'Confessor Concepcion')
          | (df4['Rep'] == 'Keith Douglas')
          | (df4['Rep'] == 'Angela Hernandez')
          | (df4['Rep'] == 'Carolina Zuluaga ') 
          | (df4['Rep'] == 'Katiria Fernandez ')
          | (df4['Rep'] == 'Brad Willinger')
          | (df4['Rep'] == 'Vincent Lee')
          | (df4['Rep'] == 'Robert Echevarria ')]

#df4

# Add type of sales for whole team

# create a list of our conditions
import numpy as np

conditions = [(df4['Rep'] == 'Yanery Fernandez') 
          | (df4['Rep'] == 'Ivonne Cedeno')
          | (df4['Rep'] == 'James (Shiou-Hao) Lu')
          | (df4['Rep'] == 'Monalisa Crossway')
          | (df4['Rep'] == 'Laura Lou Seefeldt')
          | (df4['Rep'] == 'Griselle Leonardo')
          | (df4['Rep'] == 'Shelly Bobb')
          | (df4['Rep'] == 'Zhen Zhu')
          | (df4['Rep'] == 'Confessor Concepcion')
          | (df4['Rep'] == 'Keith Douglas')
          | (df4['Rep'] == 'Angela Hernandez') ,
            (df4['Rep'] == 'Carolina Zuluaga ') 
          | (df4['Rep'] == 'Katiria Fernandez ')
          | (df4['Rep'] == 'Brad Willinger')
          | (df4['Rep'] == 'Vincent Lee')
          | (df4['Rep'] == 'Robert Echevarria ')]

# create a list of the values we want to assign for each condition
values = ['FieldSales', 'TeleSales']

# create a new column and use np.select to assign values to it using our lists as arguments
df4['type'] = np.select(conditions, values)

# Extracted only 'Enrolled'
#df5 = df4[(df4['Status'] == 'Enrolled')]

# display updated DataFrame
#df5.head()

# Cancellation

#df7 = df4[(df4['Status'] == 'Cancelled')]

# change data
#df7 = df7.replace(['MAPD'],'MAPD-C')
#df7 = df7.replace(['D-SNP'],'D-SNP-C')
#df7 = df7.replace(['I-SNP'],'I-SNP-C')
#df7 = df7.replace(['MAP'],'MAP-C')

#df7.head()

# %%
# Combine Enrollment + Cancellation (groupby table)
# df5 + df8

#frame = [df5, df7]

#df8 = pd.concat(frame)

#df8

# Add weekday

import datetime
import pandas as pd

df9 = df4
df9['WeekDay'] = df4['AppDate'].dt.day_name()

#Change format
df9['EnrollDate'] = pd.to_datetime(df9['EnrollDate'], format= '%y%m%d')
df9['AppDate'] = pd.to_datetime(df9['AppDate'], format= '%y%m%d')

df9
# Out:
#      EnrollDate    LOB     Status    AppDate                   Rep  \
# 6499 2021-01-01   MAPD   Enrolled 2020-10-15     Monalisa Crossway
# 6500 2021-01-01   MAPD  Cancelled 2020-10-15      Yanery Fernandez
# 6501 2021-01-01  D-SNP   Enrolled 2020-10-15      Yanery Fernandez
# 6502 2021-01-01   MAPD   Enrolled 2020-10-15      Yanery Fernandez
# 6503 2021-01-01  D-SNP   Enrolled 2020-10-15      Yanery Fernandez
# ...         ...    ...        ...        ...                   ...
# 7288 2021-03-01  D-SNP    Pending 2021-02-02     Carolina Zuluaga
# 7289 2021-03-01  D-SNP    Pending 2021-02-03      Yanery Fernandez
# 7290 2021-03-01  D-SNP    Pending 2021-02-03           Shelly Bobb
# 7292 2021-03-01  D-SNP    Pending 2021-02-03     Griselle Leonardo
# 7293 2021-03-01  D-SNP    Pending 2021-02-03  James (Shiou-Hao) Lu
#
#             type    WeekDay
# 6499  FieldSales   Thursday
# 6500  FieldSales   Thursday
# 6501  FieldSales   Thursday
# 6502  FieldSales   Thursday
# 6503  FieldSales   Thursday
# ...          ...        ...
# 7288   TeleSales    Tuesday
# 7289  FieldSales  Wednesday
# 7290  FieldSales  Wednesday
# 7292  FieldSales  Wednesday
# 7293  FieldSales  Wednesday
#
# [763 rows x 7 columns]

# %%
# For monthly comparison 

#df16.to_excel(r'8.xlsx', index = False)


# https://datatofish.com/export-dataframe-to-excel/

with pd.ExcelWriter('9.xlsx',
                  date_format='YYYY-MM-DD',
                  datetime_format='YYYY-MM-DD') as writer:
    df9.to_excel(writer, index=False)
