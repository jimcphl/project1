        'kh (331).pdf', 'kh (332).pdf', 'kh (333).pdf', 'kh (334).pdf','kh (335).pdf','kh (336).pdf','kh (337).pdf','kh (338).pdf','kh (339).pdf','kh (340).pdf',
        'kh (341).pdf', 'kh (342).pdf', 'kh (343).pdf', 'kh (344).pdf','kh (345).pdf','kh (346).pdf','kh (347).pdf','kh (348).pdf','kh (349).pdf','kh (350).pdf',
        'kh (351).pdf', 'kh (352).pdf', 'kh (353).pdf', 'kh (354).pdf','kh (355).pdf','kh (356).pdf','kh (357).pdf','kh (358).pdf','kh (359).pdf','kh (360).pdf',
        'kh (361).pdf', 'kh (362).pdf', 'kh (363).pdf', 'kh (364).pdf','kh (365).pdf','kh (366).pdf','kh (367).pdf','kh (368).pdf','kh (369).pdf','kh (370).pdf',
        'kh (371).pdf', 'kh (372).pdf', 'kh (373).pdf', 'kh (374).pdf','kh (375).pdf','kh (376).pdf','kh (377).pdf','kh (378).pdf','kh (379).pdf','kh (380).pdf',
        'kh (381).pdf', 'kh (382).pdf', 'kh (383).pdf', 'kh (384).pdf','kh (385).pdf','kh (386).pdf','kh (387).pdf','kh (388).pdf','kh (389).pdf','kh (390).pdf',
        'kh (391).pdf', 'kh (392).pdf', 'kh (393).pdf', 'kh (394).pdf','kh (395).pdf','kh (396).pdf','kh (397).pdf','kh (398).pdf','kh (399).pdf','kh (400).pdf',
        'kh (401).pdf', 'kh (402).pdf', 'kh (403).pdf', 'kh (404).pdf','kh (405).pdf','kh (406).pdf','kh (407).pdf','kh (408).pdf','kh (409).pdf','kh (410).pdf',
       
        'kh (411).pdf', 'kh (412).pdf', 'kh (413).pdf', 'kh (414).pdf','kh (415).pdf','kh (416).pdf','kh (417).pdf','kh (418).pdf','kh (419).pdf','kh (420).pdf',
        'kh (421).pdf', 'kh (422).pdf', 'kh (423).pdf', 'kh (424).pdf','kh (425).pdf','kh (426).pdf','kh (427).pdf','kh (428).pdf','kh (429).pdf','kh (430).pdf',
        'kh (431).pdf', 'kh (432).pdf', 'kh (433).pdf', 'kh (434).pdf','kh (435).pdf','kh (436).pdf','kh (437).pdf','kh (438).pdf','kh (439).pdf','kh (440).pdf',
        'kh (441).pdf', 'kh (442).pdf', 'kh (443).pdf', 'kh (444).pdf','kh (445).pdf','kh (446).pdf','kh (447).pdf','kh (448).pdf','kh (449).pdf','kh (450).pdf',
        'kh (451).pdf', 'kh (452).pdf', 'kh (453).pdf', 'kh (454).pdf','kh (455).pdf','kh (456).pdf','kh (457).pdf','kh (458).pdf','kh (459).pdf','kh (460).pdf',
        'kh (461).pdf', 'kh (462).pdf', 'kh (463).pdf', 'kh (464).pdf','kh (465).pdf','kh (466).pdf','kh (467).pdf','kh (468).pdf','kh (469).pdf','kh (470).pdf',
        'kh (471).pdf', 'kh (472).pdf', 'kh (473).pdf', 'kh (474).pdf','kh (475).pdf','kh (476).pdf','kh (477).pdf','kh (478).pdf','kh (479).pdf','kh (480).pdf',
        'kh (481).pdf', 'kh (482).pdf', 'kh (483).pdf', 'kh (484).pdf'
       ]



pdfFileObj = open('kh (1).pdf', 'rb')
  
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
  
# printing number of pages in pdf file
#print(pdfReader.numPages)

pageObj = pdfReader.getPage(0)
  
# extracting text from page
data_string = pageObj.extractText()


data = io.StringIO(data_string)

df6 = pd.read_csv(data, sep="\n")
#print (df.columns)

df6.rename(columns = {'Notes' : '{}'.format(a)}, 
        inplace = True)

for a in name:
    
    pdfFileObj = open(a, 'rb')
  
    # creating a pdf reader object
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
  
    # printing number of pages in pdf file
    #print(pdfReader.numPages)

    pageObj = pdfReader.getPage(0)
  
    # extracting text from page
    data_string = pageObj.extractText()


    data = io.StringIO(data_string)

    df = pd.read_csv(data, sep="\n")
    #print (df.columns)

    df.rename(columns = {'Notes' : '{}'.format(a)}, 
                    inplace = True)
                     
    #df6 = pd.join(df6, df)
    df6 = pd.concat([df6, df], axis=1)
    
print (df6)
# Out:
#       kh (484).pdf                      kh (2).pdf     kh (3).pdf  \
# 0           Reason                          Reason         Reason
# 1            Notes                           Notes          Notes
# 2             User                            User           User
# 3        Date/Time                       Date/Time      Date/Time
# 4    Admission ID:                   Admission ID:  Admission ID:
# ..             ...                             ...            ...
# 96             NaN  Report Date:  03/31/2021 14:43            NaN
# 97             NaN                             NaN            NaN
# 98             NaN                             NaN            NaN
# 99             NaN                             NaN            NaN
# 100            NaN                             NaN            NaN
#
#         kh (4).pdf     kh (5).pdf     kh (6).pdf  \
# 0           Reason         Reason         Reason
# 1            Notes          Notes          Notes
# ...

# %%
df7 = df6.iloc[[30]]

df7.reset_index(inplace = True)

# %%
df7
# Out:
#    index kh (484).pdf kh (2).pdf kh (3).pdf kh (4).pdf kh (5).pdf kh (6).pdf  \
# 0     30     6/5/2020  12/7/2020   9/1/2020  11/1/2020   9/1/2020  9/30/2020
#
#   kh (7).pdf kh (8).pdf Admission ID:  ... kh (475).pdf kh (476).pdf  \
# 0  11/2/2020   9/2/2020  IVR Call In:  ...    1/24/2021    1/15/2021
#
#   kh (477).pdf kh (478).pdf kh (479).pdf kh (480).pdf kh (481).pdf  \
# 0    1/21/2021     2/9/2021     1/5/2021     1/9/2021     2/8/2021
#
#   kh (482).pdf kh (483).pdf kh (484).pdf
# 0     2/4/2021     2/1/2021    1/17/2021
#
# [1 rows x 485 columns]

# %%
df8 = df7.T
df8['index'] = df8.index

# %%
df8
# Out:
#                       0         index
# index                30         index
# kh (484).pdf   6/5/2020  kh (484).pdf
# kh (2).pdf    12/7/2020    kh (2).pdf
# kh (3).pdf     9/1/2020    kh (3).pdf
# kh (4).pdf    11/1/2020    kh (4).pdf
# ...                 ...           ...
# kh (480).pdf   1/9/2021  kh (480).pdf
# kh (481).pdf   2/8/2021  kh (481).pdf
# kh (482).pdf   2/4/2021  kh (482).pdf
# kh (483).pdf   2/1/2021  kh (483).pdf
# kh (484).pdf  1/17/2021  kh (484).pdf
#
# [485 rows x 2 columns]

# %%
df8.to_excel(r'transpose.xlsx', index = False)

# %%
# https://cmdlinetips.com/2019/10/how-to-drop-rows-based-on-a-column-value-in-pandas-dataframe/

import pandas as pd
import os

# DualEligibleMembers.xlsx
#pd.read_excel('DualEligibleMembers.xlsx', index_col=0)

#url = "S:\ENROLLMENT\ENROLLMENT-PUBLIC\MEDICARE\MAPD\MAPD&SNP Roster_2021.xlsx"

#C:\Users\tflung\Downloads\WPy64-3870\notebooks

url = "C:\\Users\\tflung\\Downloads\\WPy64-3870\\notebooks\\transpose.xlsx"

#url = "MAPD&SNP Roster_2021.xlsx"

df9=pd.read_excel(
     os.path.join(url),
     engine='openpyxl',
)
df9
# Out:
#              0         index
# 0           30         index
# 1     6/5/2020  kh (484).pdf
# 2    12/7/2020    kh (2).pdf
# 3     9/1/2020    kh (3).pdf
# 4    11/1/2020    kh (4).pdf
# ..         ...           ...
# 480   1/9/2021  kh (480).pdf
# 481   2/8/2021  kh (481).pdf
# 482   2/4/2021  kh (482).pdf
# 483   2/1/2021  kh (483).pdf
# 484  1/17/2021  kh (484).pdf
#
# [485 rows x 2 columns]

# %%
list = set(df9[0].drop_duplicates().index)
list
# Out:
# {0,
#  1,
#  2,
#  3,
#  4,
#  6,
#  7,
#  8,
#  9,
#  13,
#  14,
#  15,
#  19,
#  20,
#  21,
#  25,
#  26,
#  27,
#  30,
#  31,
#  33,
#  35,
#  39,
#  40,
#  41,
#  45,
#  46,
#  47,
#  51,
#  52,
#  53,
#  57,
#  58,
#  59,
#  63,
#  64,
#  65,
#  69,
#  70,
#  71,
#  76,
#  77,
#  81,
#  82,
#  83,
#  87,
#  88,
#  89,
#  92,
#  93,
#  96,
#  97,
#  98,
#  102,
#  103,
#  104,
#  108,
#  109,
#  110,
#  114,
#  115,
#  116,
#  120,
#  121,
#  122,
#  126,
#  127,
#  128,
#  132,
#  133,
#  136,
#  137,
#  140,
#  141,
#  144,
#  148,
#  149,
#  152,
#  153,
#  162,
#  165,
#  173,
#  174,
#  181,
#  182,
#  191,
#  192,
#  199,
#  200,
#  207,
#  210,
#  218,
#  223,
#  226,
#  231,
#  239,
#  242,
#  249,
#  253,
#  254,
#  261,
#  262,
#  269,
#  270,
#  276,
#  277,
#  284,
#  285,
#  291,
#  292,
#  298,
#  299,
#  306,
#  307,
#  308,
#  314,
#  315,
#  316,
#  322,
#  323,
#  324,
#  330,
#  331,
#  332,
#  338,
#  339,
#  346,
#  347,
#  348,
#  354,
#  355,
#  361,
# ...

# %%
file = set(df9[df9.index.isin(list)]['index'].unique())

file
# Out:
# {'Admission ID:',
#  'index',
#  'kh (102).pdf',
#  'kh (103).pdf',
#  'kh (104).pdf',
#  'kh (108).pdf',
#  'kh (109).pdf',
#  'kh (110).pdf',
#  'kh (114).pdf',
#  'kh (115).pdf',
#  'kh (116).pdf',
#  'kh (120).pdf',
#  'kh (121).pdf',
#  'kh (122).pdf',
#  'kh (126).pdf',
#  'kh (127).pdf',
#  'kh (128).pdf',
#  'kh (13).pdf',
#  'kh (132).pdf',
#  'kh (133).pdf',
#  'kh (136).pdf',
#  'kh (137).pdf',
#  'kh (14).pdf',
#  'kh (140).pdf',
#  'kh (141).pdf',
#  'kh (144).pdf',
#  'kh (148).pdf',
#  'kh (149).pdf',
#  'kh (15).pdf',
#  'kh (152).pdf',
#  'kh (153).pdf',
#  'kh (162).pdf',
#  'kh (165).pdf',
#  'kh (173).pdf',
#  'kh (174).pdf',
#  'kh (181).pdf',
#  'kh (182).pdf',
#  'kh (19).pdf',
#  'kh (191).pdf',
#  'kh (192).pdf',
#  'kh (199).pdf',
#  'kh (2).pdf',
#  'kh (20).pdf',
#  'kh (200).pdf',
#  'kh (207).pdf',
#  'kh (21).pdf',
#  'kh (210).pdf',
#  'kh (218).pdf',
#  'kh (223).pdf',
#  'kh (226).pdf',
#  'kh (231).pdf',
#  'kh (239).pdf',
#  'kh (242).pdf',
# ...

# %%
import shutil, sys

# Copy share file to folder
# S:\ENROLLMENT\ENROLLMENT-PUBLIC\MEDICARE\MAPD
try: 
    for b in file:

        source_path = r"C:\\Users\\tflung\\Downloads\\WPy64-3870\\notebooks\\"

        # S:/MARKETING/MARKETING-PUBLIC/SALES MEDICARE TEAM/TEAM DASHBOARD/team performance
        #dest_path = r"C:\Users\tflung\Desktop"
        dest_path = r"C:\\Users\\tflung\\Downloads\\WPy64-3870\\notebooks\\Copy\\"
        file_name = b

        shutil.copyfile(source_path + file_name, dest_path + file_name)
        
except:
    pass
