# %% [markdown]
# # MAP_status

# %%
import os
import pandas as pd

url1 = "S:\ENROLLMENT\ENROLLMENT-PUBLIC\MEDICARE\MAP\Source\MAP Roster_2021- KAT2.xlsx"

df20=pd.read_excel(
     os.path.join(url1),
     engine='openpyxl',
     sheet_name='Enrolled'
)

df21=pd.read_excel(
     os.path.join(url1),
     engine='openpyxl',
     sheet_name='Not Enrolled'
)

# Enrollment Tracking
df30=pd.read_excel(
     os.path.join(url1),
     engine='openpyxl',
     sheet_name='Enrollment Tracking'
)

# Withdrawal Cancel Tracking
df31=pd.read_excel(
     os.path.join(url1),
     engine='openpyxl',
     sheet_name='Withdrawal Cancel Tracking'
)

# Withdrawal Cancel Tracking
df42=pd.read_excel(
     os.path.join(url1),
     engine='openpyxl',
     sheet_name='Disenrolled'
)


# Rename
#Overall Start Date

df20 = df20.rename(columns={'Legacy ID': 'ID'})
df20 = df20.rename(columns={'Overall Status': 'Status'})
df20 = df20.rename(columns={'Medicare Start Date': 'EnrollDate'})
df20 = df20.rename(columns={'Overall End Date': 'DisenrollDate'})
df20 = df20.rename(columns={'Sales Agent': 'Agent'})
df20 = df20.rename(columns={'Member Last Name': 'Last'})
df20 = df20.rename(columns={'Member First Name': 'First'})
# Application Date
df20 = df20.rename(columns={'Application Date': 'appDate'})
df20['EnrollDate'] = pd.to_datetime(df20['EnrollDate'], errors = 'coerce')
df20['DisenrollDate'] = pd.to_datetime(df20['DisenrollDate'], errors = 'coerce')
df20['appDate'] = pd.to_datetime(df20['appDate'], errors = 'coerce')


df21 = df21.rename(columns={'Legacy ID': 'ID'})
df21 = df21.rename(columns={'Overall Status': 'Status'})
df21 = df21.rename(columns={'Medicare Start Date': 'EnrollDate'})
df21 = df21.rename(columns={'Overall End Date': 'DisenrollDate'})
df21 = df21.rename(columns={'Sales Agent': 'Agent'})
df21 = df21.rename(columns={'Member Last Name': 'Last'})
df21 = df21.rename(columns={'Member First Name': 'First'})
df21['EnrollDate'] = pd.to_datetime(df21['EnrollDate'], errors = 'coerce')
df21['DisenrollDate'] = pd.to_datetime(df21['DisenrollDate'], errors = 'coerce')



df30 = df30.rename(columns={'Legacy ID': 'ID'})
df30 = df30.rename(columns={'Overall Status': 'Status'})
df30 = df30.rename(columns={'Medicare Start Date': 'EnrollDate'})
df30 = df30.rename(columns={'Overall End Date': 'DisenrollDate'})
df30 = df30.rename(columns={'Sales Agent': 'Agent'})
df30 = df30.rename(columns={'Member Last Name': 'Last'})
df30 = df30.rename(columns={'Member First Name': 'First'})
df30['EnrollDate'] = pd.to_datetime(df30['EnrollDate'], errors = 'coerce')
df30['DisenrollDate'] = pd.to_datetime(df30['DisenrollDate'], errors = 'coerce')


df31 = df31.rename(columns={'Legacy ID': 'ID'})
df31 = df31.rename(columns={'Overall Status': 'Status'})
df31 = df31.rename(columns={'Medicare Start Date': 'EnrollDate'})
df31 = df31.rename(columns={'Overall End Date': 'DisenrollDate'})
df31 = df31.rename(columns={'Sales Agent': 'Agent'})
df31 = df31.rename(columns={'Member Last Name': 'Last'})
df31 = df31.rename(columns={'Member First Name': 'First'})
df31['EnrollDate'] = pd.to_datetime(df31['EnrollDate'], errors = 'coerce')
df31['DisenrollDate'] = pd.to_datetime(df31['DisenrollDate'], errors = 'coerce')


df42 = df42.rename(columns={'Legacy ID': 'DID'})
df42 = df42.rename(columns={'Overall Status': 'Status'})
df42 = df42.rename(columns={'Medicare Start Date': 'EnrollDate'})
df42 = df42.rename(columns={'Overall End Date': 'DisenrollDate'})
df42 = df42.rename(columns={'Medicare Disenrollment Reason': 'Reason'})
df42 = df42.rename(columns={'Medicare Disenrollment Type': 'Type'})
df42 = df42.rename(columns={'Member Last Name': 'Last'})
df42 = df42.rename(columns={'Member First Name': 'First'})
df42['EnrollDate'] = pd.to_datetime(df42['EnrollDate'], errors = 'coerce')
df42['DisenrollDate'] = pd.to_datetime(df42['DisenrollDate'], errors = 'coerce')


df42 = df42[['DID', 'EnrollDate', 'DisenrollDate', 'Status', 'Last', 'First', 'Reason', 'Type'
            ]]

#print (list(df9.columns))

# select columns

df20 = df20[['ID', 'EnrollDate', 'DisenrollDate', 'LOB', 'Status', 'Agent', 'Last', 'First', 'appDate']]

#df3 = df2[['DisenrollDate', 'EnrollDate', 'LOB', 'Status', 'AppDate', 'Rep']]
df21 = df21[['ID', 'EnrollDate', 'DisenrollDate', 'LOB', 'Status', 'Agent', 'Last', 'First']]
# Out:
# C:\Users\tflung\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# BD MAP Cases Tracker

# Remove file
import os
if os.path.exists("C:/Users/tflung/Downloads/BD MAP Cases Tracker.xlsx"):
  os.remove("C:/Users/tflung/Downloads/BD MAP Cases Tracker.xlsx")
else:
  print("The file does not exist")


# Download file
import subprocess
import webbrowser
import sys

url = 'https://app.smartsheet.com/sheets/r3Wf7HmHGqfgmxq3XgGg46Gh7R34HfwHqQ4929W1?view=grid&filterId=6906122398394244'
if sys.platform == 'darwin':    # in case of OS X
    subprocess.Popen(['open', url])
else:
    webbrowser.open_new_tab(url)

# %%
import pandas as pd
import os

# DualEligibleMembers.xlsx
#pd.read_excel('DualEligibleMembers.xlsx', index_col=0)

url = 'C:/Users/tflung/Downloads/BD MAP Cases Tracker.xlsx'

#url = "MAPD&SNP Roster_2021.xlsx"

df1=pd.read_excel(
     os.path.join(url),
     engine='openpyxl',
)
df1['Prospect/Member Card ID'] = df1['Prospect/Member Card ID'].astype(int)
df1
# Out:
# C:\Users\tflung\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     Primary Column        BD Sales Rep Name SOA Receipt  Date  \
# 0              NaN           Brad Willinger        2011-11-02
# 1              NaN         Yanery Fernandez        2021-09-01
# 2              NaN        Katiria Fernandez        2021-09-09
# 3              NaN        Katiria Fernandez        2021-09-14
# 4              NaN  Paula Andrea Luna Lopez        2021-09-28
# ..             ...                      ...               ...
# 246            NaN           Brad Willinger        2022-01-14
# 247            NaN    Ivonne Cedeno Mendoza        2022-01-21
# 248            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 249            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 250            NaN         Yanery Fernandez        2022-01-29
#
#             Prospect Name Language  Prospect/Member Card ID Medicaid ID  \
# 0          Mohammed Islam      NaN                    61258    NK47277K
# 1         Phulmattee Khan  English                    59848    SR14541N
# 2            Coraisia Ali      NaN                    41816    NE82371K
# 3         Carol Shoemaker      NaN                   132347    XS92890H
# 4    PAULA PEREZ-GONZALEZ  Spanish                   314751    XN66745R
# ..                    ...      ...                      ...         ...
# 246         Armando Elias      NaN                   323399    ZU69407G
# 247           DAISY RAMOS      NaN                   323965    ZX09450A
# 248          Maria Campos      NaN                   119317    TB95207N
# 249          Nydia Nieves      NaN                   119323    TB90542S
# 250           Avi Muradov      NaN                   146526    SZ32223B
#
#             SOA Outcome Date Pushed by ENR for Scheduling  \
# 0        Not Interested                        2021-11-11
# 1    Ready for Schedule                        2021-09-01
# 2                   NaN                        2021-09-10
# 3                   NaN                        2021-09-15
# 4    Ready for Schedule                        2021-09-28
# ..                  ...                               ...
# 246                 NaN                        2022-01-18
# 247                 NaN                        2022-01-21
# 248                 NaN                        2022-01-24
# 249                 NaN                        2022-01-24
# 250                 NaN                        2022-01-19
#
#     Dept. Scheduling Case Projected ENR Effective Date BD Rep Comments  \
# 0                  Intake          2022-01-01 00:00:00             NaN
# 1        Care Coordinator          2021-11-01 00:00:00             NaN
# 2                  Intake          2021-12-01 00:00:00             NaN
# 3        Care Coordinator          2021-11-01 00:00:00             NaN
# 4        Care Coordinator          2021-11-01 00:00:00             NaN
# ..                    ...                          ...             ...
# 246                Intake          2022-02-01 00:00:00             NaN
# 247                Intake          2022-03-01 00:00:00             NaN
# 248      Care Coordinator          2022-03-01 00:00:00             NaN
# 249      Care Coordinator          2022-03-01 00:00:00             NaN
# 250                Intake          2022-02-01 00:00:00             NaN
#
#        UAS Scheduling Status Attempt Count UAS Date Scheduled  \
# 0          Request call back   2nd Attempt                NaT
# 1                  Scheduled           NaN         2021-10-07
# 2    BD Rep follow up needed           NaN                NaT
# 3                  Scheduled           NaN         2021-09-27
# 4                  Scheduled           NaN         2021-10-19
# ..                       ...           ...                ...
# 246             Left message   1st Attempt                NaT
# 247                Scheduled   2nd Attempt         2022-02-15
# 248                      NaN           NaN                NaT
# 249                      NaN           NaN                NaT
# 250        Request call back   1st Attempt                NaT
#
#             Intake/Retention/Care Coordinator Comments FA/RN UAS Outcome  \
# 0    Called prospect @ 917 535 4372 he request call...               NaN
# 1                                                  NaN      Accepted POC
# 2                     No action needed from MAP Intake               NaN
# 3                                                  NaN      Accepted POC
# 4                                                  NaN      Accepted POC
# ..                                                 ...               ...
# 246  Lacier 01/22 Called prospect, no answer. LVM r...               NaN
# 247  Lacier: 01/22 Spoke with prospect, HIPPA verif...               NaN
# 248                                                NaN               NaN
# 249                                                NaN               NaN
# 250  Lacier: 01/22 Spoke with prospect, whom right ...               NaN
#
#     Ready for MAP Application App follow up Status App Received Date
# 0                          No                  NaN               NaT
# 1                         Yes            Submitted        2021-10-27
# 2                         Yes            Submitted        2021-11-12
# 3                         Yes            Withdrawn               NaT
# 4                         Yes            Submitted        2021-10-27
# ..                        ...                  ...               ...
# 246                        No                  NaN               NaT
# 247                        No                  NaN               NaT
# 248                        No                  NaN               NaT
# 249                        No                  NaN               NaT
# 250                        No                  NaN               NaT
#
# [251 rows x 20 columns]

# %%
# Same ID

same = list(set(df20['ID']).intersection(set(df1['Prospect/Member Card ID'])))
len(same)
# Out:
# 90

# %%
import numpy as np

df1["Enrolled"] = np.where(df1["Prospect/Member Card ID"].isin(same), "Yes", "No")
df1
# Out:
#     Primary Column        BD Sales Rep Name SOA Receipt  Date  \
# 0              NaN           Brad Willinger        2011-11-02
# 1              NaN         Yanery Fernandez        2021-09-01
# 2              NaN        Katiria Fernandez        2021-09-09
# 3              NaN        Katiria Fernandez        2021-09-14
# 4              NaN  Paula Andrea Luna Lopez        2021-09-28
# ..             ...                      ...               ...
# 246            NaN           Brad Willinger        2022-01-14
# 247            NaN    Ivonne Cedeno Mendoza        2022-01-21
# 248            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 249            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 250            NaN         Yanery Fernandez        2022-01-29
#
#             Prospect Name Language  Prospect/Member Card ID Medicaid ID  \
# 0          Mohammed Islam      NaN                    61258    NK47277K
# 1         Phulmattee Khan  English                    59848    SR14541N
# 2            Coraisia Ali      NaN                    41816    NE82371K
# 3         Carol Shoemaker      NaN                   132347    XS92890H
# 4    PAULA PEREZ-GONZALEZ  Spanish                   314751    XN66745R
# ..                    ...      ...                      ...         ...
# 246         Armando Elias      NaN                   323399    ZU69407G
# 247           DAISY RAMOS      NaN                   323965    ZX09450A
# 248          Maria Campos      NaN                   119317    TB95207N
# 249          Nydia Nieves      NaN                   119323    TB90542S
# 250           Avi Muradov      NaN                   146526    SZ32223B
#
#             SOA Outcome Date Pushed by ENR for Scheduling  \
# 0        Not Interested                        2021-11-11
# 1    Ready for Schedule                        2021-09-01
# 2                   NaN                        2021-09-10
# 3                   NaN                        2021-09-15
# 4    Ready for Schedule                        2021-09-28
# ..                  ...                               ...
# 246                 NaN                        2022-01-18
# 247                 NaN                        2022-01-21
# 248                 NaN                        2022-01-24
# 249                 NaN                        2022-01-24
# 250                 NaN                        2022-01-19
#
#     Dept. Scheduling Case  ... BD Rep Comments    UAS Scheduling Status  \
# 0                  Intake  ...             NaN        Request call back
# 1        Care Coordinator  ...             NaN                Scheduled
# 2                  Intake  ...             NaN  BD Rep follow up needed
# 3        Care Coordinator  ...             NaN                Scheduled
# 4        Care Coordinator  ...             NaN                Scheduled
# ..                    ...  ...             ...                      ...
# 246                Intake  ...             NaN             Left message
# 247                Intake  ...             NaN                Scheduled
# 248      Care Coordinator  ...             NaN                      NaN
# 249      Care Coordinator  ...             NaN                      NaN
# 250                Intake  ...             NaN        Request call back
#
#     Attempt Count UAS Date Scheduled  \
# 0     2nd Attempt                NaT
# 1             NaN         2021-10-07
# 2             NaN                NaT
# 3             NaN         2021-09-27
# 4             NaN         2021-10-19
# ..            ...                ...
# 246   1st Attempt                NaT
# 247   2nd Attempt         2022-02-15
# 248           NaN                NaT
# 249           NaN                NaT
# 250   1st Attempt                NaT
#
#             Intake/Retention/Care Coordinator Comments FA/RN UAS Outcome  \
# 0    Called prospect @ 917 535 4372 he request call...               NaN
# 1                                                  NaN      Accepted POC
# 2                     No action needed from MAP Intake               NaN
# 3                                                  NaN      Accepted POC
# 4                                                  NaN      Accepted POC
# ..                                                 ...               ...
# 246  Lacier 01/22 Called prospect, no answer. LVM r...               NaN
# 247  Lacier: 01/22 Spoke with prospect, HIPPA verif...               NaN
# 248                                                NaN               NaN
# 249                                                NaN               NaN
# 250  Lacier: 01/22 Spoke with prospect, whom right ...               NaN
#
#     Ready for MAP Application App follow up Status App Received Date Enrolled
# 0                          No                  NaN               NaT       No
# 1                         Yes            Submitted        2021-10-27      Yes
# 2                         Yes            Submitted        2021-11-12      Yes
# 3                         Yes            Withdrawn               NaT       No
# 4                         Yes            Submitted        2021-10-27      Yes
# ..                        ...                  ...               ...      ...
# 246                        No                  NaN               NaT       No
# 247                        No                  NaN               NaT       No
# 248                        No                  NaN               NaT       No
# 249                        No                  NaN               NaT       No
# 250                        No                  NaN               NaT       No
#
# [251 rows x 21 columns]

# %%
same1 = list(set(df30['ID']).intersection(set(df1['Prospect/Member Card ID'])))
len(same1)
# Out:
# 55

# %%
df1["Pending"] = np.where(df1["Prospect/Member Card ID"].isin(same1), "Yes", "No")

df1
# Out:
#     Primary Column        BD Sales Rep Name SOA Receipt  Date  \
# 0              NaN           Brad Willinger        2011-11-02
# 1              NaN         Yanery Fernandez        2021-09-01
# 2              NaN        Katiria Fernandez        2021-09-09
# 3              NaN        Katiria Fernandez        2021-09-14
# 4              NaN  Paula Andrea Luna Lopez        2021-09-28
# ..             ...                      ...               ...
# 246            NaN           Brad Willinger        2022-01-14
# 247            NaN    Ivonne Cedeno Mendoza        2022-01-21
# 248            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 249            NaN    Ivonne Cedeno Mendoza        2022-01-22
# 250            NaN         Yanery Fernandez        2022-01-29
#
#             Prospect Name Language  Prospect/Member Card ID Medicaid ID  \
# 0          Mohammed Islam      NaN                    61258    NK47277K
# 1         Phulmattee Khan  English                    59848    SR14541N
# 2            Coraisia Ali      NaN                    41816    NE82371K
# 3         Carol Shoemaker      NaN                   132347    XS92890H
# 4    PAULA PEREZ-GONZALEZ  Spanish                   314751    XN66745R
# ..                    ...      ...                      ...         ...
# 246         Armando Elias      NaN                   323399    ZU69407G
# 247           DAISY RAMOS      NaN                   323965    ZX09450A
# 248          Maria Campos      NaN                   119317    TB95207N
# 249          Nydia Nieves      NaN                   119323    TB90542S
# 250           Avi Muradov      NaN                   146526    SZ32223B
#
#             SOA Outcome Date Pushed by ENR for Scheduling  \
# 0        Not Interested                        2021-11-11
# 1    Ready for Schedule                        2021-09-01
# 2                   NaN                        2021-09-10
# 3                   NaN                        2021-09-15
# 4    Ready for Schedule                        2021-09-28
# ..                  ...                               ...
# 246                 NaN                        2022-01-18
# 247                 NaN                        2022-01-21
# 248                 NaN                        2022-01-24
# 249                 NaN                        2022-01-24
# 250                 NaN                        2022-01-19
#
#     Dept. Scheduling Case  ...    UAS Scheduling Status Attempt Count  \
# 0                  Intake  ...        Request call back   2nd Attempt
# 1        Care Coordinator  ...                Scheduled           NaN
# 2                  Intake  ...  BD Rep follow up needed           NaN
# 3        Care Coordinator  ...                Scheduled           NaN
# 4        Care Coordinator  ...                Scheduled           NaN
# ..                    ...  ...                      ...           ...
# 246                Intake  ...             Left message   1st Attempt
# 247                Intake  ...                Scheduled   2nd Attempt
# 248      Care Coordinator  ...                      NaN           NaN
# 249      Care Coordinator  ...                      NaN           NaN
# 250                Intake  ...        Request call back   1st Attempt
#
#     UAS Date Scheduled         Intake/Retention/Care Coordinator Comments  \
# 0                  NaT  Called prospect @ 917 535 4372 he request call...
# 1           2021-10-07                                                NaN
# 2                  NaT                   No action needed from MAP Intake
# 3           2021-09-27                                                NaN
# 4           2021-10-19                                                NaN
# ..                 ...                                                ...
# 246                NaT  Lacier 01/22 Called prospect, no answer. LVM r...
# 247         2022-02-15  Lacier: 01/22 Spoke with prospect, HIPPA verif...
# 248                NaT                                                NaN
# 249                NaT                                                NaN
# 250                NaT  Lacier: 01/22 Spoke with prospect, whom right ...
#
#     FA/RN UAS Outcome Ready for MAP Application App follow up Status  \
# 0                 NaN                        No                  NaN
# 1        Accepted POC                       Yes            Submitted
# 2                 NaN                       Yes            Submitted
# 3        Accepted POC                       Yes            Withdrawn
# 4        Accepted POC                       Yes            Submitted
# ..                ...                       ...                  ...
# 246               NaN                        No                  NaN
# 247               NaN                        No                  NaN
# 248               NaN                        No                  NaN
# 249               NaN                        No                  NaN
# 250               NaN                        No                  NaN
#
#     App Received Date Enrolled Pending
# 0                 NaT       No      No
# 1          2021-10-27      Yes      No
# 2          2021-11-12      Yes      No
# 3                 NaT       No      No
# 4          2021-10-27      Yes      No
# ..                ...      ...     ...
# 246               NaT       No     Yes
# 247               NaT       No     Yes
# 248               NaT       No     Yes
# 249               NaT       No     Yes
# 250               NaT       No     Yes
#
# [251 rows x 22 columns]

# %%
# https://datatofish.com/export-dataframe-to-excel/

df1.to_excel(r'BD_tracking.xlsx', index = False)


import os

# C:\Users\tflung\Downloads\WPy64-3870\notebooks


os.chdir('C:\\Users\\tflung\\Downloads\\WPy64-3870\\notebooks')

os.system('start excel.exe "BD_tracking.xlsx"')
# Out:
# 0
